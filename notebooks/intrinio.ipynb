# %%
import sys

sys.path.insert(0, '../lib') if '../lib'!=sys.path[0] else None
from intrinio import IntrinioApi

import pyonepassword
api = IntrinioApi(pyonepassword.OP().item_get('Intrinio').first_field_by_label('API Key Production').value)
df = api.security_prices('SPY', '2023-01-01')
#df = api.option_prices('SPY221019C00390000')
df
# Out:
#          date  intraperiod frequency     open     high       low   close  \
# 51 2023-01-03        False     daily  384.370  386.430  377.8310  380.82
# 50 2023-01-04        False     daily  383.180  385.880  380.0000  383.76
# 49 2023-01-05        False     daily  381.720  381.840  378.7600  379.38
# 48 2023-01-06        False     daily  382.610  389.250  379.4127  388.08
# 47 2023-01-09        False     daily  390.370  393.700  387.6700  387.86
# 46 2023-01-10        False     daily  387.250  390.650  386.2700  390.58
# 45 2023-01-11        False     daily  392.230  395.600  391.3800  395.52
# 44 2023-01-12        False     daily  396.670  398.485  392.4200  396.96
# 43 2023-01-13        False     daily  393.620  399.100  393.3400  398.50
# 42 2023-01-17        False     daily  398.480  400.230  397.0600  397.77
# 41 2023-01-18        False     daily  399.010  400.120  391.2800  391.49
# 40 2023-01-19        False     daily  389.360  391.080  387.2600  388.64
# ...
